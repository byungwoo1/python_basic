# %% [markdown]
# ## 프로그래밍 시작

# %% [markdown]
# ## Python이란?

# %% [markdown]
# * Python은 네덜란드 출신의 컴퓨터 프로그래머이자 구글, 드롭박스를 거쳐 현재는 MS 개발자인 귀도 반 로섬(Guido Van Rossum)이 1991년에 발표한 프로그래밍 언어입니다.
#   - (1989년 12월, 귀도는 취미가 될만한 프로젝트를 찾고 있었고 마침 크리스마스 휴일이라 사무실 문을 닫으면서 집에 있는 컴퓨터로 Python 개발에 착수하였다고 전해집니다)
#
# * Python이라는 이름은 당시 귀도가 좋아하던 코미디 쇼였던 "Monty Python's Flying Circus"에서 따온 것입니다.
#   - Python은 그리스 신화에서 나오는 큰 뱀입니다.
#   - Python 로고는 뱀 모양입니다.
#   - Python의 버전은 2와 3이 있습니다.

# %% [markdown]
# ## Python의 특징?

# %% [markdown]
# * Python은 인간다운 언어이므로 사람이 생각하는 방식으로 프로그래밍합니다.
#   - 영어를 모국어로 하는 사람들에게 해당합니다. 최소한 한글은 아니니까요.
# * Python은 문법이 쉬워 빠르게 배울 수 있습니다.
#   - 프로그래밍에 익숙하다면 일주일이면 충분하겠지만, 초심자에게는 절대로 아닙니다.
# * Python은 오픈소스이므로 무료고, 수많은 라이브러리를 사용할 수 있습니다.
#   - 라이브러리 설치 에러가 발생하고, 일관성이 부족한 것도 오픈소스의 특징입니다.
# - Python은 간경하고, 들여쓰기 규칙으로 코드 가독성을 높일 수 있습니다.

# %% [markdown]
# --- Life is too short, you need python! ---

# %% [markdown]
# ## 기본 구문 : 코드 입력 및 실행

# %% [markdown]
# * Python을 실행하면 콘솔이 열리고, 콘솔 왼쪽에 >>> 기호(프롬프트)가 있습니다.
#   - 프롬프트 오른쪽에서 커서가 깜빡거립니다.
# * Python은 스크립트 언어이므로 콘솔에서 코드를 입력하고 [enter]키를 누르면 코드 실행 결과를 코드 아래에 출력합니다.[대화식 모드]
# * 여러 줄 코드를 입력하고 실행하려면 IDLE 편집기를 이용합니다.[스크립트 모드]
#   - IDLE 편집기에서 [enter]키를 누르면 코드를 실행하지 않고 커서를 아래로 옯깁니다.
#   - 실행할 코드를 py 파일로 저장하고 상단 메뉴에서 Run --> Run Module 버튼을 차례대로 클릭하면 py 파일을 실행합니다.

# %% [markdown]
# ## Jupyter Notebook 메인화면

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Jupyter Notebook 셀 모드

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## jupyter Notebook 주요 단축키(명령모드에서 실행)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Jupyter Notebook 매직 명령어

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## [참고] 키보드의 주요 키 위치

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 변수와 객체

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 객체의 생성과 확인

# %%
# a에 정수 10을 할당합니다.
a = 10

# %%
# 변수명만 실행하면 변수가 가리키는 객체를 출력합니다.
# [참고] 여러 줄 코드 사이에 세미콜론을 추가하면 한 줄로 작성할 수 있습니다.
a
# Out:
# 10

# %%
# print() 함수는 변수가 가리키는 객체를 표준 출력 위치에 출력합니다.
print(a)
# [참고] 변수명을 실행한 결과와 다를 수 있습니다. 문자열은 따옴표를 출력하지 않습니다.
# Out:
# 10

# %%
# type() 함수는 변수가 가리키는 객체의 클래스를 반환합니다.
type(a)
# [참고] 같은 클래스 함수로 생성한 객체는 같은 속성과 방식을 갖습니다.
# Out:
# int

# %%
# dir() 함수는 변수가 갖는 속성과 방식을 리스트로 반환합니다.
dir(a)
# a에 많은 속성과 방식이 있지만 알파벳으로 시작하는 것만 사용합니다.(ex. as_integer_ratio, bit count등)
# [참고] 밑줄로 시작하는 속성과 방식은 특별한 기능을 갖습니다.
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %% [markdown]
# ## 객체의 속성과 방식에 접근

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# numerator는 int의 속성이며 분자를 출력합니다.
a.numerator
# [주의] 객체의 속성 뒤에 광호를 추가하면 에러를 반환합니다.
# Out:
# 10

# %%
# denominator는 int의 속성이며 분모를 출력합니다.
a.denominator
# Out:
# 1

# %%
# bit_length는 int의 방식이며 10진수를 2진수로 변환할 때 길이를 반환합니다.
a.bit_length()
# [주의] 방식 뒤에 괄호를 생략하면 에러를 반환한다.
# Out:
# 4

# %% [markdown]
# ## End of Document
