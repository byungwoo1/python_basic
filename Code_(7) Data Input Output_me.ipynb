# %% [markdown]
# # 데이터 입출력

# %% [markdown]
# ### 작업 경로

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 절대 경로 VS 상대 경로

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 작업 경로 확인 및 변경

# %%
# 관련 라이브러리를 호출합니다.
import os # os 라이브러리는 작업 경로 설정과 관련한 함수를 포함하고 있습니다.

# %%
# 현재 작업 경로를 확인합니다.
os.getcwd() # 현재 작업 경로는 PythonBasic-main/code 폴더입니다.
            # [참고] Jupyter Notebook 파일이 있는 폴더로 현재 작업 경로를 자동 설정합니다.
# Out:
# 'D:\\python\\PythonBasic-main\\code'

# %% [raw]
# # 데이터 파일이 있는 폴더로 작업 경로를 변경합니다.(절대 경로)
# os.chdir(path = 'C:\\Users\\계정명\\Documents\\PythonBasic-main\\data')

# %%
# 현재 작업 경로를 다시 확인합니다.
os.getcwd() # 현재 작업 경로는 PythonBasic-main/data 폴더입니다.
# Out:
# 'D:\\python\\PythonBasic-main\\code'

# %%
# 상위 폴더로 작업 경로를 변경합니다.(상대 경로)
os.chdir(path = '..')

# %%
# 현재 작업 경로를 다시 확인합니다.
os.getcwd() # 현재 작업 경로는 PythonBasic-main 폴더입니다.
# Out:
# 'D:\\python\\PythonBasic-main\\code'

# %%
# 데이터 파일이 있는 폴더로 작업 경로를 변경합니다.(상대 경로)
os.chdir(path = './data') # 이번 강의에서는 상대 경로를 사용하여 작업 경로를 변경합니다.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 # 데이터 파일이 있는 폴더로 작업 경로를 변경합니다.(상대 경로)
# ----> 2 os.chdir(path = './data')
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: './data'

# %%
# 현재 작업 경로를 다시 확인합니다.
os.getcwd() # 현재 작업 경로는 PythonBasic-main/data 폴더입니다.
# Out:
# 'D:\\python\\PythonBasic-main\\code'

# %% [markdown]
# ### 작업 경로에 있는 폴더명과 파일명 확인

# %% [raw]
# * 현재 작업 경로에 있는 폴더명과 파일명을 출력합니다.

# %%
os.listdir() # 현재 작업 경로에 있는 폴더명과 파일명을 리스트로 반환합니다.
# Out:
# ['(1) Variable and Object_me.ipynb',
#  '(2) Data Type_me.ipynb',
#  '(3) Data Structure_me.ipynb',
#  '(4) Basic Grammar_me.ipynb',
#  '(5) Numpy Basic_me.ipynb',
#  '(6) Pandas Basic_me.ipynb',
#  '(7) Data Input Output_me.ipynb',
#  '.ipynb_checkpoints',
#  '.~Data Type_me.ipynb',
#  '01 Variable and Object.ipynb',
#  '02 Data Type.ipynb',
#  '03 Data Structure.ipynb',
#  '04 Basic Grammar.ipynb',
#  '05 Numpy Basic.ipynb',
#  '06 Pandas Basic.ipynb',
#  '07 Data Input Output.ipynb',
#  '08 Data Preprocessing.ipynb',
#  '09 Data Visualization.ipynb',
#  'MyFunc.py',
#  'myFuncs.py',
#  '__pycache__']

# %%
# [참고] path 매개변수에 경로명을 문자열로 지정하면 해당 경로에 있는
# 폴더명과 파일명을 리스트로 반환합니다.
os.listdir(path = '../code')
# Out:
# ['(1) Variable and Object_me.ipynb',
#  '(2) Data Type_me.ipynb',
#  '(3) Data Structure_me.ipynb',
#  '(4) Basic Grammar_me.ipynb',
#  '(5) Numpy Basic_me.ipynb',
#  '(6) Pandas Basic_me.ipynb',
#  '(7) Data Input Output_me.ipynb',
#  '.ipynb_checkpoints',
#  '.~Data Type_me.ipynb',
#  '01 Variable and Object.ipynb',
#  '02 Data Type.ipynb',
#  '03 Data Structure.ipynb',
#  '04 Basic Grammar.ipynb',
#  '05 Numpy Basic.ipynb',
#  '06 Pandas Basic.ipynb',
#  '07 Data Input Output.ipynb',
#  '08 Data Preprocessing.ipynb',
#  '09 Data Visualization.ipynb',
#  'MyFunc.py',
#  'myFuncs.py',
#  '__pycache__']

# %% [raw]
# * [Mac 사용자만!] 현재 작업 경로를 출력했을 때 오름차순 정렬하여 출력합니다.

# %%
files = os.listdir() # [참고] Windows는 파일명과 폴더명을 오름차순 정렬하여 리스트로 반환하지만 
                     # MacOS는 문자열을 정렬하지 않고 반환하는 경우가 있습니다.
files.sort() # files는 리스트이므로, 리스트의 원소를 오름차순 정렬하려면 sort() 함수를 실행합니다.
             # [참고] sort() 함수는 실행 결과를 리스트에 반영하므로 재할당하지 않아도 됩니다.
files # files를 출력하면 오름차순 정렬되어 있습니다. 외부 파일을 읽을 때 파일명을 직접 타이핑하지 말고
      # 출력된 파일명을 복사하여 붙여넣기 하면 타이핑 에러를 피할 수 있습니다.
# Out:
# ['(1) Variable and Object_me.ipynb',
#  '(2) Data Type_me.ipynb',
#  '(3) Data Structure_me.ipynb',
#  '(4) Basic Grammar_me.ipynb',
#  '(5) Numpy Basic_me.ipynb',
#  '(6) Pandas Basic_me.ipynb',
#  '(7) Data Input Output_me.ipynb',
#  '.ipynb_checkpoints',
#  '.~Data Type_me.ipynb',
#  '01 Variable and Object.ipynb',
#  '02 Data Type.ipynb',
#  '03 Data Structure.ipynb',
#  '04 Basic Grammar.ipynb',
#  '05 Numpy Basic.ipynb',
#  '06 Pandas Basic.ipynb',
#  '07 Data Input Output.ipynb',
#  '08 Data Preprocessing.ipynb',
#  '09 Data Visualization.ipynb',
#  'MyFunc.py',
#  '__pycache__',
#  'myFuncs.py']

# %% [markdown]
# ### [참고] 한글 인코딩의 이해

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### [참고] 한글 인코딩 방식 관계도

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 새 텍스트 파일 생성

# %% [raw]
# * 쓰기모드로 텍스트 파일을 엽니다.

# %%
file = open(file = 'test.txt', mode = 'w', encoding = 'UTF-8')
# 현재 작업 경로에 있는 'test.txt' 파일을 쓰기 모드로 엽니다. 파일이 없으면 새로 생성합니다.
# [참고] Windows 사용자는 encoding을 추가하지 않으면 'CP949'를 자동 적용합니다

# %% [raw]
# * 텍스트 파일에 문자열을 입력합니다.

# %%
for i in range(1, 6): # 반복문을 실행하여 여러 문자열을 텍스트 파일에 입력합니다.
    file.write(f'{i} 페이지 수집!\n')

# %%
# 텍스트 파일을 닫습니다.
file.close() # 텍스트 파일을 닫으면 텍스트 파일을 저장합니다.

# %% [markdown]
# ### 기존 텍스트 파일에 문자열 추가

# %%
# 추가모드로 텍스트 파일을 엽니다.
file = open(file = 'test.txt', mode = 'a', encoding = 'UTF-8')
# 현재 작업 경로에 있는 'test.txt' 파일을 추가모드로 엽니다. 파일이 없으면 새로 생성합니다.

# %%
# 텍스트 파일에 문자열을 입력합니다.
for i in range(11, 16):
    file.write(f'{i} 페이지 수집!\n')

# %%
# 텍스트 파일을 닫습니다.
file.close()

# %% [markdown]
# ### 텍스트 파일을 문자열로 읽기

# %%
# 문자열 읽기모드로 텍스트 파일을 엽니다.
file = open(file = 'test.txt', mode = 'r', encoding = 'UTF-8')
# 현재 작업 경로에 있는 'test.txt' 파일을 읽기모드로 엽니다. 파일이 없으면 에러를 반환합니다.

# %%
# file을 읽고 text에 할당합니다.
text = file.read() # read() 함수는 file을 사람이 읽을 수 있는 문자열(str)로 반환합니다.
                   # [참고] readlines() 함수는 리스트로 반환합니다.
text

# %%
# text의 클래스를 확인합니다. text의 클래스는 str입니다.
# [참고] str은 사람이 읽을 수 있는 문자열입니다.
type(text)

# %%
# 문자열을 인코딩하면 바이너리 코드로 변환합니다.
text.encode(encoding = 'UTF-8')

# %% [markdown]
# ### 텍스트 파일을 바이너리로 읽기

# %% [raw]
# * 바이너리 읽기모드로 텍스트 파일을 엽니다.

# %%
# [주의] 바이너리 모드로 읽을 때 인코딩 방식을 추가할 수 없습니다.
file = open(file = 'test.txt', mode = 'rb')
# 현재 작업 경로에 있는 'test.txt' 파일을 바이너리 읽기모드로 엽니다. 파일이 없으면 에러를 반환합니다.

# %% [raw]
# * 텍스트 파일을 읽고 출력합니다.

# %%
# file을 읽고 text에 할당합니다.
text = file.read()
text

# %%
# text의 클래스를 확인합니다. text의 클래스는 bytes입니다.
# [참고] bytes는 사람이 읽을 수 없는 코드 입니다.
type(text)

# %%
# 바이너리 코드를 디코딩하면 문자열로 변환합니다.
text.decode(encoding = 'UTF-8')
# [주의] Windows에서 'test.txt' 파일을 생성할 때 encoding = 'UTF-8'를 추가하지 않았다면
# 반드시 'EUC-KR' 또는 'CP949'를 지정해야 합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 # 바이너리 코드를 디코딩하면 문자열로 변환합니다.
# ----> 2 text.decode(encoding = 'UTF-8')
#
# NameError: name 'text' is not defined

# %% [markdown]
# ### 관련 라이브러리 호출

# %% [raw]
# # 관련 라이브러리를 설치합니다.
# !pip install chardet # chardet 라이브러리를 설치합니다. 왼쪽 코드는 한 번만 실행합니다.
#                      # [참고] Jupyter Notebook에서 라이브러리를 설치하려면 느낌표를 추가합니다.
# !pip install joblib # joblib 라이브러리를 설치합니다.

# %%
# 관련 라이브러리를 호출합니다.
import chardet # 텍스트 파일의 문자열 인코딩 방식을 확인하는 함수를 포함하고 있습니다.
import numpy as np
import pandas as pd
import joblib # Python 객체를 압축 파일로 저장하고 호출하는 함수를 포함하고 있습니다.

# %% [markdown]
# ### xlsx 파일 입출력

# %% [raw]
# * xlsx 파일을 읽고 데이터프레임을 생성합니다.

# %%
df = pd.read_excel(io = 'KBO_Hitters_2021.xlsx',  # [참고] 만약 코드 에러가 발생하면 openpyxl 하이브러리를 설치하세요
                   sheet_name = 'Hitters',  # 시트 인덱스 또는 시트명 하나만 지정합니다(기본값 :0)
                   skiprows = 4) # 열이름 위로 생략할 행 개수를 지정합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df = pd.read_excel(io = 'KBO_Hitters_2021.xlsx',  # [참고] 만약 코드 에러가 발생하면 openpyxl 하이브러리를 설치하세요
#       2                    sheet_name = 'Hitters',  # 시트 인덱스 또는 시트명 하나만 지정합니다(기본값 :0)
#       3                    skiprows = 4)
#
# NameError: name 'pd' is not defined

# %% [raw]
# * df를 출력합니다.

# %%
df
# [참고] 데이터프레임의 행과 열 개수가 많으면 모든 행과 열을 출력하지 않고 결과 창 크기에 따라 출력할
# 행과 열 개수를 자동 계산하며, 생략하는 행과 열 사이에 ... 기호를 대신 출력합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
* 데이터프레임을 xlsx 파일로 저장합니다.

# %%
df.to_excel(excel_writer = 'test.xlsx', index = None)
# index = None을 추가하면 xlsx 파일을 저장할 때 인덱스를 삭제합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df.to_excel(excel_writer = 'test.xlsx', index = None)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### [참고] 데이터프레임 행/열 최대 출력 옵션 변경

# %% [raw]
# * 최대 행 출력 옵션을 확인합니다.

# %%
pd.get_option('display.max_rows') # 최대 행 출력 개수를 출력합니다.(기본값::60)
                                  # [참고] 최대 열 출력 개수는 max_columns를 사용합니다.

# %%
# 최대 행 출력 옵션에 None을 할당하면 전체 행을 출력합니다.
pd.set_option('display.max_rows', None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # 최대 행 출력 옵션에 None을 할당하면 전체 행을 출력합니다.
# ----> 2 pd.set_option('display.max_rows', None)
#
# NameError: name 'pd' is not defined

# %% [raw]
# * df를 출력하면 전체 행을 출력합니다.

# %%
df # [참고] 전체 행을 출력하도록 옵션을 변경하면 Jupyter Notebook이 느려지거나 다운될 수 있습니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [raw]
# * 최대 행 출력 옵션을 초기화합니다.

# %%
pd.reset_option('display.max_rows') # [참고] 전체 옵션을 초기화하려면 'all'을 지정합니다.

# %%
# 최대 행 출력 옵션을 확인합니다.
pd.options.display.max_rows # 왼쪽 코드를 싱행하면 최대 행 출력 개수를 출력합니다.

# %% [markdown]
# ### 데이터프레임 미리보기

# %% [raw]
# * 데이터프레임의 처음 5행을 출력합니다.

# %%
df.head() # [참고] n 매개변수에 입력하는 개수만큼 출력합니다.(기본값:5)

# %%
# 데이터프레임의 처음 10행을 출력합니다.
df.head(n = 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 # 데이터프레임의 처음 10행을 출력합니다.
# ----> 2 df.head(n = 10)
#
# NameError: name 'df' is not defined

# %% [raw]
# * 데이터프레임의 마지막 5행을 출력합니다.

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %% [raw]
# * 데이터프레임을 무작위로 1행을 추출합니다.

# %%
df.sample()
# [참고] n 매개변수에 입력하는 개수만큼 출력합니다.(기본값:None)
# random_state 매개변수에 같은 정수를 지정하면 항상 같은 결과를 반환합니다.

# %% [markdown]
# ### csv 파일 입출력

# %% [raw]
# * csv 파일명을 재사용할 수 있도록 변수에 할당합니다.

# %%
file = 'KBO_Hitters_2021.csv'

# %% [raw]
# * csv 파일을 읽고 데이터프레임을 생성합니다.

# %% [raw]
# df = pd.read_csv(filepath_or_buffer = file)
# # [주의] csv 파일의 인토딩 방식이 'UTF-8'이 아니면 인코딩 방식을 지정해야 합니다.

# %% [raw]
# * csv 파일을 바이너리 모드로 읽습니다.

# %%
text = open(file = file, mode = 'rb').read()
# [참고] text는 bytes 코드이므로 출력하면 사람이 읽을 수 없습니다.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 text = open(file = file, mode = 'rb').read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'KBO_Hitters_2021.csv'

# %% [raw]
# * csv 파일의 문자 인코딩 방식을 확인합니다.

# %%
chardet.detect(text)
# [참고] 바이너리 코드의 인토딩 방식과 신뢰도(confidence)를 반환합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 chardet.detect(text)
#
# NameError: name 'chardet' is not defined

# %% [raw]
# * csv 파일의 인코딩 방식을 지정하여 다시 읽습니다.

# %%
df = pd.read_csv(filepath_or_buffer = file, encoding = 'EUC-KR')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 # csv 파일의 인코딩 방식을 지정하여 다시 읽습니다.
# ----> 2 df = pd.read_csv(filepath_or_buffer = file, encoding = 'EUC-KR')
#
# NameError: name 'pd' is not defined

# %% [raw]
# * df의 인덱스를 정수 1부터 시작하도록 변경합니다.

# %%
df.index = range(1, df.shape[0] + 1) #[참고] df.shape은 행과 열 개수를 튜플로 반환합니다.

# %%
# df의 처음 5행을 출력합니다.
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 # df의 처음 5행을 출력합니다.
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %% [raw]
# * 데이터프레임을 csv 파일로 저장합니다.

# %%
df.to_csv(path_or_buf = 'test.csv', index = None, encoding = 'UTF-8')
# [참고] csv 파일의 인코딩 방식을 지정할 수 있습니다.

# %% [markdown]
# ### 압축 파일 입출력

# %% [raw]
# * 데이터프레임을 포함한 모든 Python 객체를 외부 파일로 저장하려면 압축 파일을 사용하는 것이 좋습니다.
#    - joblib 라이브러리는 Python 객체를 다양한 형태의 압축 파일로 저장하고,
#      압축 파일을 Python으로 호출하는 함수를 포함하고 있습니다.

# %% [raw]
# * df를 확장자가 z인 압축 파일로 저장합니다.

# %%
joblib.dump(value = df, filename = 'test.z')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 joblib.dump(value = df, filename = 'test.z')
#
# NameError: name 'joblib' is not defined

# %% [raw]
# * z 파일을 호출하고 데이터프레임에 할당합니다.

# %%
df1 = joblib.load(filename = 'test.z')

# %% [markdown]
# ### [참고] 실습 파일 삭제

# %% [raw]
# * 현재 작업 경로에서 'test'를 포함하는 파일명으로 리스트를 생성합니다.

# %%
files = [file for file in os.listdir() if 'test' in file]
files # files는 이번 시간에 생성한 4개 파일명을 원소로 갖습니다.
# Out:
# ['test.txt']

# %% [raw]
# * 반복문으로 해당 파일을 모두 삭제합니다.

# %%
for file in files:
    os.remove(path = file) # [참고] os.remove() 함수는 한 번에 하나의 파일을 삭제합니다.

# %% [raw]
# * 현재 작업 경로에 있는 폴더명과 파일명을 출력합니다.

# %%
os.listdir() # 'test'를 포함하는 파일을 모두 삭제했습니다.
# Out:
# ['(1) Variable and Object_me.ipynb',
#  '(2) Data Type_me.ipynb',
#  '(3) Data Structure_me.ipynb',
#  '(4) Basic Grammar_me.ipynb',
#  '(5) Numpy Basic_me.ipynb',
#  '(6) Pandas Basic_me.ipynb',
#  '(7) Data Input Output_me.ipynb',
#  '.ipynb_checkpoints',
#  '.~Data Type_me.ipynb',
#  '01 Variable and Object.ipynb',
#  '02 Data Type.ipynb',
#  '03 Data Structure.ipynb',
#  '04 Basic Grammar.ipynb',
#  '05 Numpy Basic.ipynb',
#  '06 Pandas Basic.ipynb',
#  '07 Data Input Output.ipynb',
#  '08 Data Preprocessing.ipynb',
#  '09 Data Visualization.ipynb',
#  'MyFunc.py',
#  'myFuncs.py',
#  '__pycache__']

# %% [markdown]
# ### [참고] 프로야구 타자 스탯 데이터 간단 설명

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## End of Document
